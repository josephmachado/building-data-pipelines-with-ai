# %%
! uv run python ./generate_data.py

# %%
! uv run python ./run_ddl.py

# %%
! uv run python ./fct_orders.py --start-time 1995-01-01 --end-time 1996-01-01
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# Run pi skill design-pipeline-no-mcp

# %%
! uv run python ./fct_line_items.py --start-time 1995-01-01 --end-time 1996-01-01

# %%
! uv run which python

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("run-ddl").master("local[*]").getOrCreate()

# %%
spark.sql("show tables in prod").show()

# %%
spark.sql("show schemas").show()

# %%
spark.sql("select * from local.silver.fct_orders limit 4").show()

# %%
spark.sql("select * from local.silver.fct_line_items limit 4").show()

# %%
https://pi.dev/packages/pi-mcp-extension
